# %%
import pandas as pd

# %% [markdown]
# READ CSV FILE

# %%
dataframe = pd.read_csv("archive/songs.csv")

# %% [markdown]
# 1. SIMPLE DATA PREPROCESSING (remove newline chars, drop duplicates, remove short lyrics)

# %%
def  lyricPreprocess (frame : pd.DataFrame )  -> pd.DataFrame:
    # Remove newline chars
    frame['lyrics'] = frame['lyrics'].str.replace(r"\\n", " ", regex=True)
    frame['lyrics'] = frame['lyrics'].str.replace("\n", " ", regex=True)
    frame['lyrics'] = frame['lyrics'].str.replace("\r", " ", regex=True)
    #drop duplicates 
    frame['lyrics'] = frame['lyrics'].drop_duplicates()
    #remove short lyrics
    frame= frame[frame['lyrics'].notna() & (frame['lyrics'].str.len() > 250)]     
    
    return  frame[['lyrics','genre']]

# %% [markdown]
# SEE IF THE DATASET IS BALANCED

# %%
def getStatisticsOnDataset (frame : pd.DataFrame) -> pd.DataFrame : 
    #count duplicates based on lyrics 
    counts = frame['lyrics'].value_counts()
    counts = counts[counts > 1]
    print('Duplicates :' ,frame['lyrics'].duplicated().sum())
    genre_percent = frame['genre'].value_counts(normalize=True) * 100
    print(genre_percent)

# %% [markdown]
# need to drop duplicates since there are "deluxe" versions of some songs
# lets get 2500 from each genre for the 4 top genres, so 10000 in total

# %%
selectedGenres = ['Rock', 'Pop', 'Electronic', 'Folk']

# %%
def getBalancedSubset(frame : pd.DataFrame)  -> pd.DataFrame:
    return frame[frame['genre'].isin(selectedGenres)].groupby('genre').sample(n=2500, random_state=69).reset_index(drop=True)

# %%
def preProcessPipeLine(frame : pd.DataFrame) : 
    frame = lyricPreprocess(frame=frame)
    frame = getBalancedSubset(frame=frame)
    getStatisticsOnDataset(frame=frame)
    frame.to_csv('archive/balancedSubset.csv', index=True, encoding='utf-8')

# %%
preProcessPipeLine(frame=dataframe)
# Out:
# Duplicates : 0
# genre
# Electronic    25.0
# Folk          25.0
# Pop           25.0
# Rock          25.0
# Name: proportion, dtype: float64

# %%
dataframe = pd.read_csv("archive/balancedSubset.csv")
