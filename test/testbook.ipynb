# %%
import genbert
from pandas import DataFrame
import importlib
importlib.reload(genbert)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_1484/1447398318.py in <cell line: 0>()
# ----> 1 import genbert
#       2 from pandas import DataFrame
#       3 import importlib
#       4 importlib.reload(genbert)
#
# ModuleNotFoundError: No module named 'genbert'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from genbert import loadDataFrame, preProcessPipeLine

# %%
import genbert.model


genbert.model.training_pipeline()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 import genbert.model
#       4 genbert.model.training_pipeline()
#
# File ~/nlp/test/genbert/model.py:6
#       2 #INSTALL THE FOLLOWING PACKAGES IF NECESSARY
#       3
#       4 #!pip install datasets evaluate scikit-learn matplotlib
# ----> 6 from datasets import load_dataset,ClassLabel, Dataset, DatasetDict
#       7 from transformers import Trainer,AutoTokenizer,AutoModelForSequenceClassification,TrainingArguments,EarlyStoppingCallback
#       8 import numpy as np
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages/datasets/__init__.py:17
#       1 # Copyright 2020 The HuggingFace Datasets Authors and the TensorFlow Datasets Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
# ...
